# %%
import numpy as np

# %% [markdown]
#  *** README***
#   - 하단의 proten score matrix 셀 들을 실행시켜주세요. (score matrix files를 불러오기 위함)
#   - substitution matrix files는 최종 제출 zip에 함께 첨부하였습니다.
#   - 자세한 실행 과정은 아래의 안내에 따라 진행해주세요.

# %% [markdown]
# ## **PROTEIN score matrix**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
file_path = '/content/drive/MyDrive/score_matrix'

# %% [markdown]
# ### **Score Matrix files**

# %% [markdown]
# ####BLOSUM62 불러오기

# %%
with open(os.path.join(file_path,'BLOSUM62.txt')) as f:
    lines = f.read().splitlines()

# %%
BLOSUM62 = []
for i in range(len(lines)):
  BLOSUM62.append(lines[i].split())

for i in range(len(lines)):
  del BLOSUM62[i][-1]

del BLOSUM62[-1]

BLOSUM62[0].insert(0,' ')

# %%
for i in range(len(lines)-1):
  print(BLOSUM62[i])
# Out:
# [' ', 'A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V', 'B', 'J', 'Z', 'X']
# ['A', '4', '-1', '-2', '-2', '0', '-1', '-1', '0', '-2', '-1', '-1', '-1', '-1', '-2', '-1', '1', '0', '-3', '-2', '0', '-2', '-1', '-1', '-1']
# ['R', '-1', '5', '0', '-2', '-3', '1', '0', '-2', '0', '-3', '-2', '2', '-1', '-3', '-2', '-1', '-1', '-3', '-2', '-3', '-1', '-2', '0', '-1']
# ['N', '-2', '0', '6', '1', '-3', '0', '0', '0', '1', '-3', '-3', '0', '-2', '-3', '-2', '1', '0', '-4', '-2', '-3', '4', '-3', '0', '-1']
# ['D', '-2', '-2', '1', '6', '-3', '0', '2', '-1', '-1', '-3', '-4', '-1', '-3', '-3', '-1', '0', '-1', '-4', '-3', '-3', '4', '-3', '1', '-1']
# ['C', '0', '-3', '-3', '-3', '9', '-3', '-4', '-3', '-3', '-1', '-1', '-3', '-1', '-2', '-3', '-1', '-1', '-2', '-2', '-1', '-3', '-1', '-3', '-1']
# ['Q', '-1', '1', '0', '0', '-3', '5', '2', '-2', '0', '-3', '-2', '1', '0', '-3', '-1', '0', '-1', '-2', '-1', '-2', '0', '-2', '4', '-1']
# ...

# %% [markdown]
# ####PAM250 불러오기

# %%
with open(os.path.join(file_path,'PAM250.txt')) as f:
    lines = f.read().splitlines()

# %%
PAM250 = []
for i in range(len(lines)):
  PAM250.append(lines[i].split())

for i in range(len(lines)):
  del PAM250[i][-1]

del PAM250[-1]

PAM250[0].insert(0,' ')

# %%
for i in range(len(lines)-1):
  print(PAM250[i])
# Out:
# [' ', 'A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V', 'B', 'J', 'Z', 'X']
# ['A', '2', '-2', '0', '0', '-2', '0', '0', '1', '-1', '-1', '-2', '-1', '-1', '-3', '1', '1', '1', '-6', '-3', '0', '0', '-1', '0', '-1']
# ['R', '-2', '6', '0', '-1', '-4', '1', '-1', '-3', '2', '-2', '-3', '3', '0', '-4', '0', '0', '-1', '2', '-4', '-2', '-1', '-3', '0', '-1']
# ['N', '0', '0', '2', '2', '-4', '1', '1', '0', '2', '-2', '-3', '1', '-2', '-3', '0', '1', '0', '-4', '-2', '-2', '2', '-3', '1', '-1']
# ['D', '0', '-1', '2', '4', '-5', '2', '3', '1', '1', '-2', '-4', '0', '-3', '-6', '-1', '0', '0', '-7', '-4', '-2', '3', '-3', '3', '-1']
# ['C', '-2', '-4', '-4', '-5', '12', '-5', '-5', '-3', '-3', '-2', '-6', '-5', '-5', '-4', '-3', '0', '-2', '-8', '0', '-2', '-4', '-5', '-5', '-1']
# ['Q', '0', '1', '1', '2', '-5', '4', '2', '-1', '3', '-2', '-2', '1', '-1', '-5', '0', '-1', '-1', '-5', '-4', '-2', '1', '-2', '3', '-1']
# ...

# %% [markdown]
# ####PAM30 불러오기

# %%
with open(os.path.join(file_path,'PAM30.txt')) as f:
    lines = f.read().splitlines()

# %%
PAM30 = []
for i in range(len(lines)):
  PAM30.append(lines[i].split())

for i in range(len(lines)):
  del PAM30[i][-1]

del PAM30[-1]

PAM30[0].insert(0,' ')

# %%
for i in range(len(lines)-1):
  print(PAM30[i])
# Out:
# [' ', 'A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V', 'B', 'J', 'Z', 'X']
# ['A', '6', '-7', '-4', '-3', '-6', '-4', '-2', '-2', '-7', '-5', '-6', '-7', '-5', '-8', '-2', '0', '-1', '-13', '-8', '-2', '-3', '-6', '-3', '-1']
# ['R', '-7', '8', '-6', '-10', '-8', '-2', '-9', '-9', '-2', '-5', '-8', '0', '-4', '-9', '-4', '-3', '-6', '-2', '-10', '-8', '-7', '-7', '-4', '-1']
# ['N', '-4', '-6', '8', '2', '-11', '-3', '-2', '-3', '0', '-5', '-7', '-1', '-9', '-9', '-6', '0', '-2', '-8', '-4', '-8', '6', '-6', '-3', '-1']
# ['D', '-3', '-10', '2', '8', '-14', '-2', '2', '-3', '-4', '-7', '-12', '-4', '-11', '-15', '-8', '-4', '-5', '-15', '-11', '-8', '6', '-10', '1', '-1']
# ['C', '-6', '-8', '-11', '-14', '10', '-14', '-14', '-9', '-7', '-6', '-15', '-14', '-13', '-13', '-8', '-3', '-8', '-15', '-4', '-6', '-12', '-9', '-14', '-1']
# ...

# %% [markdown]
# ####PAM70 불러오기

# %%
with open(os.path.join(file_path,'PAM70.txt')) as f:
    lines = f.read().splitlines()

# %%
PAM70 = []
for i in range(len(lines)):
  PAM70.append(lines[i].split())

for i in range(len(lines)):
  del PAM70[i][-1]

del PAM70[-1]

PAM70[0].insert(0,' ')

# %% [markdown]
# ####BLOSUM45 불러오기

# %%
with open(os.path.join(file_path,'BLOSUM45.txt')) as f:
    lines = f.read().splitlines()

# %%
BLOSUM45 = []
for i in range(len(lines)):
  BLOSUM45.append(lines[i].split())

for i in range(len(lines)):
  del BLOSUM45[i][-1]

del BLOSUM45[-1]

BLOSUM45[0].insert(0,' ')

# %% [markdown]
# ####BLOSUM50 불러오기

# %%
with open(os.path.join(file_path,'BLOSUM50.txt')) as f:
    lines = f.read().splitlines()

# %%
BLOSUM50 = []
for i in range(len(lines)):
  BLOSUM50.append(lines[i].split())

for i in range(len(lines)):
  del BLOSUM50[i][-1]

del BLOSUM50[-1]

BLOSUM50[0].insert(0,' ')

# %% [markdown]
# ####BLOSUM80 불러오기

# %%
with open(os.path.join(file_path,'BLOSUM80.txt')) as f:
    lines = f.read().splitlines()

# %%
BLOSUM80 = []
for i in range(len(lines)):
  BLOSUM80.append(lines[i].split())

for i in range(len(lines)):
  del BLOSUM80[i][-1]

del BLOSUM80[-1]

BLOSUM80[0].insert(0,' ')

# %% [markdown]
# ####BLOSUM90 불러오기

# %%
with open(os.path.join(file_path,'BLOSUM90.txt')) as f:
    lines = f.read().splitlines()

# %%
BLOSUM90 = []
for i in range(len(lines)):
  BLOSUM90.append(lines[i].split())

for i in range(len(lines)):
  del BLOSUM90[i][-1]

del BLOSUM90[-1]

BLOSUM90[0].insert(0,' ')

# %%
for i in range(len(lines)-1):
  print(BLOSUM90[i])
# Out:
# [' ', 'A', 'R', 'N', 'D', 'C', 'Q', 'E', 'G', 'H', 'I', 'L', 'K', 'M', 'F', 'P', 'S', 'T', 'W', 'Y', 'V', 'B', 'J', 'Z', 'X']
# ['A', '5', '-2', '-2', '-3', '-1', '-1', '-1', '0', '-2', '-2', '-2', '-1', '-2', '-3', '-1', '1', '0', '-4', '-3', '-1', '-2', '-2', '-1', '-1']
# ['R', '-2', '6', '-1', '-3', '-5', '1', '-1', '-3', '0', '-4', '-3', '2', '-2', '-4', '-3', '-1', '-2', '-4', '-3', '-3', '-2', '-3', '0', '-1']
# ['N', '-2', '-1', '7', '1', '-4', '0', '-1', '-1', '0', '-4', '-4', '0', '-3', '-4', '-3', '0', '0', '-5', '-3', '-4', '5', '-4', '-1', '-1']
# ['D', '-3', '-3', '1', '7', '-5', '-1', '1', '-2', '-2', '-5', '-5', '-1', '-4', '-5', '-3', '-1', '-2', '-6', '-4', '-5', '5', '-5', '1', '-1']
# ['C', '-1', '-5', '-4', '-5', '9', '-4', '-6', '-4', '-5', '-2', '-2', '-4', '-2', '-3', '-4', '-2', '-2', '-4', '-4', '-2', '-4', '-2', '-5', '-1']
# ...

# %% [markdown]
# ###**Matrix score**

# %%
def matrix_score1(amino1,amino2):
  a = 0
  b = 0
  c = -100000
  for i in range(1,len(BLOSUM62),1):
    if BLOSUM62[0][i] == amino1:
      a = i
  for i in range(1,len(BLOSUM62),1):
    if BLOSUM62[i][0] == amino2:
      b = i
  
  c = BLOSUM62[a][b]

  return c

# %%
def matrix_score2(amino1,amino2):
  a = 0
  b = 0
  c = -100000
  for i in range(1,len(PAM250),1):
    if PAM250[0][i] == amino1:
      a = i
  for i in range(1,len(PAM250),1):
    if PAM250[i][0] == amino2:
      b = i
  
  c = PAM250[a][b]

  return c

# %%
def matrix_score3(amino1,amino2):
  a = 0
  b = 0
  c = -100000
  for i in range(1,len(PAM30),1):
    if PAM30[0][i] == amino1:
      a = i
  for i in range(1,len(PAM30),1):
    if PAM30[i][0] == amino2:
      b = i
  
  c = PAM30[a][b]

  return c

# %%
def matrix_score4(amino1,amino2):
  a = 0
  b = 0
  c = -100000
  for i in range(1,len(PAM70),1):
    if PAM70[0][i] == amino1:
      a = i
  for i in range(1,len(PAM70),1):
    if PAM70[i][0] == amino2:
      b = i
  
  c = PAM70[a][b]

  return c

# %%
def matrix_score5(amino1,amino2):
  a = 0
  b = 0
  c = -100000
  for i in range(1,len(BLOSUM45),1):
    if BLOSUM45[0][i] == amino1:
      a = i
  for i in range(1,len(BLOSUM45),1):
    if BLOSUM45[i][0] == amino2:
      b = i
  
  c = BLOSUM45[a][b]

  return c

# %%
def matrix_score6(amino1,amino2):
  a = 0
  b = 0
  c = -100000
  for i in range(1,len(BLOSUM50),1):
    if BLOSUM50[0][i] == amino1:
      a = i
  for i in range(1,len(BLOSUM50),1):
    if BLOSUM50[i][0] == amino2:
      b = i
  
  c = BLOSUM50[a][b]

  return c

# %%
def matrix_score7(amino1,amino2):
  a = 0
  b = 0
  c = -100000
  for i in range(1,len(BLOSUM80),1):
    if BLOSUM80[0][i] == amino1:
      a = i
  for i in range(1,len(BLOSUM80),1):
    if BLOSUM80[i][0] == amino2:
      b = i
  
  c = BLOSUM80[a][b]

  return c

# %%
def matrix_score8(amino1,amino2):
  a = 0
  b = 0
  c = -100000
  for i in range(1,len(BLOSUM90),1):
    if BLOSUM90[0][i] == amino1:
      a = i
  for i in range(1,len(BLOSUM90),1):
    if BLOSUM90[i][0] == amino2:
      b = i
  
  c = BLOSUM90[a][b]

  return c

# %% [markdown]
# # **DNA or PROTEIN**

# %% [markdown]
# 📘 DNA 를 선택하실 경우 1을, PROTEIN을 선택하실 경우 2를 입력해주세요.
#
# 📘 실행을 마친 후, 다시 실행하고 싶다면 런타임을 다시 시작해주세요.

# %%
select = int(input("DNA or PROTEIN? : "))
# Out:
# DNA or PROTEIN? : 2

# %%
if select == 1:
  seq1 = input("first seq : ") # seq 1 입력
  lseq1 = list(seq1)
  seq2 = input("second seq : ") # seq 2 입력
  lseq2 = list(seq2)
  gap_score = input("gap score : ") # gap score 입력
  match_score = input("match score : ") # match score 입력
  mismatch_score = input("mismatch score : ") # mismatch score 입력

  score_matrix = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]
  for i in range(2,len(seq1)+2,1):
  #print(i)
    score_matrix[0][i] = lseq1[i-2]
  #print(score_matrix[0][i])
  for i in range(2,len(lseq2)+2,1):
    score_matrix[i][0] = lseq2[i-2]
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix[1][i] = '0'
    else:
      a = int(score_matrix[1][i-1]) + int(gap_score)
      score_matrix[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix[i][1] = '0'
    else:
      a = int(score_matrix[i-1][1]) + int(gap_score)
      score_matrix[i][1] = str(a)

  direction_matrix = np.zeros((3,len(seq2)+2,len(seq1)+2))
  for i in range(2,len(seq2)+2,1):
    for j in range(2,len(seq1)+2,1):
      if score_matrix[i][0] == score_matrix[0][j]:
        s = match_score
      else:
        s = mismatch_score
    
      s1 = int(score_matrix[i-1][j-1]) + int(s)
      s2 = int(score_matrix[i-1][j]) + int(gap_score)
      s3 = int(score_matrix[i][j-1]) + int(gap_score)
    
      score_matrix[i][j] = str(max(s1,s2,s3))

      if str(max(s1,s2,s3)) == str(s1):
      #대각선 방향
        direction_matrix[0][i][j] = 1
      if str(max(s1,s2,s3)) == str(s2):
        direction_matrix[1][i][j] = 1
      if str(max(s1,s2,s3)) == str(s3):
        direction_matrix[2][i][j] = 1

  print('score_matrix:')
  for i in range(len(seq2)+2):
    print(score_matrix[i])
  
  start_seq1 = len(seq1)+1
  start_seq2 = len(seq2)+1
  rev_seq1 = []
  rev_seq2 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print(i)
      #print(j)

      if i == start_seq2 and j == start_seq1:
        #print(start_seq2)
        #print(start_seq1)

        if direction_matrix[0][i][j] == 1:
          sc1 = int(score_matrix[i-1][j-1])
        else:
          sc1 = -1000000
      
        if direction_matrix[1][i][j] == 1:
          sc2 = int(score_matrix[i-1][j])
        else:
          sc2 = -1000000
      
        if direction_matrix[2][i][j] == 1:
          sc3 = int(score_matrix[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1.append(score_matrix[0][j])
          rev_seq2.append(score_matrix[i][0])
          start_seq1 = start_seq1 - 1
          start_seq2 = start_seq2 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1.append('-')
          rev_seq2.append(score_matrix[i][0])
          start_seq2 = start_seq2 - 1

        else:
          rev_seq1.append(score_matrix[0][j])
          rev_seq2.append('-')
          start_seq1 = start_seq1 - 1
      
        if start_seq2==1 and start_seq1==2:
          rev_seq1.append(score_matrix[0][start_seq1])
          rev_seq2.append('-')
          break

        elif start_seq2==2 and start_seq1==1:
          rev_seq1.append('-')
          rev_seq2.append(score_matrix[start_seq2][0])
          break
  rev_seq1.reverse()
  rev_seq2.reverse()
  print(f'rev_seq1 : {rev_seq1}')
  print(f'rev_seq2 : {rev_seq2}')
  best_seq1 = "".join(rev_seq1)
  best_seq2 = "".join(rev_seq2)
  print("---DNA Global Alignment---")
  print("best seq1 : ",best_seq1)
  print("best seq2 : ",best_seq2)
############################################################

else :
  seq1 = input("first seq : ") # seq 1 입력
  lseq1 = list(seq1)
  seq2 = input("second seq : ") # seq 2 입력
  lseq2 = list(seq2)
  gap_opening = input("gap opening penalty : ") # gap opening penalty
  gap_extension_penalty = input("gap extension penalty : ") #gap extension penalty
  direction_matrix1 = np.zeros((3,len(seq2)+2,len(seq1)+2))
  direction_matrix2 = np.zeros((3,len(seq2)+2,len(seq1)+2))
  direction_matrix3 = np.zeros((3,len(seq2)+2,len(seq1)+2))
  direction_matrix4 = np.zeros((3,len(seq2)+2,len(seq1)+2))
  direction_matrix5 = np.zeros((3,len(seq2)+2,len(seq1)+2))
  direction_matrix6 = np.zeros((3,len(seq2)+2,len(seq1)+2))
  direction_matrix7 = np.zeros((3,len(seq2)+2,len(seq1)+2))
  direction_matrix8 = np.zeros((3,len(seq2)+2,len(seq1)+2))
  import numpy as np
  # 0으로 score matrix 초기화
  #score_matrix1
  score_matrix1 = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]

  for i in range(2,len(seq1)+2,1):
    score_matrix1[0][i] = lseq1[i-2]

  for i in range(2,len(lseq2)+2,1):
    score_matrix1[i][0] = lseq2[i-2]

  # gap score 추가 
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix1[1][i] = '0'
    else:
      a = int(score_matrix1[1][i-1]) + int(gap_opening)
      score_matrix1[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix1[i][1] = '0'
    else:
      a = int(score_matrix1[i-1][1]) + int(gap_opening)
      score_matrix1[i][1] = str(a) 

  #score_matrix2
  score_matrix2 = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]

  for i in range(2,len(seq1)+2,1):
    score_matrix2[0][i] = lseq1[i-2]

  for i in range(2,len(lseq2)+2,1):
    score_matrix2[i][0] = lseq2[i-2]

  # gap score 추가 
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix2[1][i] = '0'
    else:
      a = int(score_matrix2[1][i-1]) + int(gap_opening)
      score_matrix2[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix2[i][1] = '0'
    else:
      a = int(score_matrix2[i-1][1]) + int(gap_opening)
      score_matrix2[i][1] = str(a)   

  #score_matrix3
  score_matrix3 = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]

  for i in range(2,len(seq1)+2,1):
    score_matrix3[0][i] = lseq1[i-2]

  for i in range(2,len(lseq2)+2,1):
    score_matrix3[i][0] = lseq2[i-2]

  # gap score 추가 
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix3[1][i] = '0'
    else:
      a = int(score_matrix3[1][i-1]) + int(gap_opening)
      score_matrix3[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix3[i][1] = '0'
    else:
      a = int(score_matrix3[i-1][1]) + int(gap_opening)
      score_matrix3[i][1] = str(a) 

  #score_matrix4
  score_matrix4 = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]

  for i in range(2,len(seq1)+2,1):
    score_matrix4[0][i] = lseq1[i-2]

  for i in range(2,len(lseq2)+2,1):
    score_matrix4[i][0] = lseq2[i-2]

# gap score 추가 
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix4[1][i] = '0'
    else:
      a = int(score_matrix4[1][i-1]) + int(gap_opening)
      score_matrix4[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix4[i][1] = '0'
    else:
      a = int(score_matrix4[i-1][1]) + int(gap_opening)
      score_matrix4[i][1] = str(a)  

 #score_matrix5
  score_matrix5 = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]

  for i in range(2,len(seq1)+2,1):
    score_matrix5[0][i] = lseq1[i-2]

  for i in range(2,len(lseq2)+2,1):
    score_matrix5[i][0] = lseq2[i-2]

  # gap score 추가 
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix5[1][i] = '0'
    else:
      a = int(score_matrix5[1][i-1]) + int(gap_opening)
      score_matrix5[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix5[i][1] = '0'
    else:
      a = int(score_matrix5[i-1][1]) + int(gap_opening)
      score_matrix5[i][1] = str(a) 

 #score_matrix6
  score_matrix6 = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]

  for i in range(2,len(seq1)+2,1):
    score_matrix6[0][i] = lseq1[i-2]

  for i in range(2,len(lseq2)+2,1):
    score_matrix6[i][0] = lseq2[i-2]

  # gap score 추가 
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix6[1][i] = '0'
    else:
      a = int(score_matrix6[1][i-1]) + int(gap_opening)
      score_matrix6[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix6[i][1] = '0'
    else:
      a = int(score_matrix6[i-1][1]) + int(gap_opening)
      score_matrix6[i][1] = str(a) 

 #score_matrix7
  score_matrix7 = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]

  for i in range(2,len(seq1)+2,1):
    score_matrix7[0][i] = lseq1[i-2]

  for i in range(2,len(lseq2)+2,1):
    score_matrix7[i][0] = lseq2[i-2]

  # gap score 추가 
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix7[1][i] = '0'
    else:
      a = int(score_matrix7[1][i-1]) + int(gap_opening)
      score_matrix7[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix7[i][1] = '0'
    else:
      a = int(score_matrix7[i-1][1]) + int(gap_opening)
      score_matrix7[i][1] = str(a) 
 #score_matrix8
  score_matrix8 = [['0'] * (len(seq1)+2) for _ in range(len(seq2)+2) ]

  for i in range(2,len(seq1)+2,1):
    score_matrix8[0][i] = lseq1[i-2]

  for i in range(2,len(lseq2)+2,1):
    score_matrix8[i][0] = lseq2[i-2]

  # gap score 추가 
  for i in range(1,len(seq1)+2,1):
    if i == 1:
      score_matrix8[1][i] = '0'
    else:
      a = int(score_matrix8[1][i-1]) + int(gap_opening)
      score_matrix8[1][i] = str(a)

  for i in range(1,len(seq2)+2,1):
    if i == 1:
      score_matrix8[i][1] = '0'
    else:
      a = int(score_matrix8[i-1][1]) + int(gap_opening)
      score_matrix8[i][1] = str(a) 
###
  for i in range(2,len(seq2)+2,1):
   for j in range(2,len(seq1)+2,1):
     s1 = int(score_matrix1[i-1][j-1]) + int(matrix_score1(score_matrix1[i][0],score_matrix1[0][j]))
     s2 = int(score_matrix1[i-1][j]) + int(gap_opening)
     s3 = int(score_matrix1[i][j-1]) + int(gap_opening)
     
     score_matrix1[i][j] = str(max(s1,s2,s3))
     if str(max(s1,s2,s3)) == str(s1):  #대각선 방향
      direction_matrix1[0][i][j] = 1
     if str(max(s1,s2,s3)) == str(s2):
      direction_matrix1[1][i][j] = 1
     if str(max(s1,s2,s3)) == str(s3):
      direction_matrix1[2][i][j] = 1

  for i in range(2,len(seq2)+2,1):
   for j in range(2,len(seq1)+2,1):
     s1 = int(score_matrix2[i-1][j-1]) + int(matrix_score2(score_matrix2[i][0],score_matrix2[0][j]))
     s2 = int(score_matrix2[i-1][j]) + int(gap_opening)
     s3 = int(score_matrix2[i][j-1]) + int(gap_opening)
     
     score_matrix2[i][j] = str(max(s1,s2,s3))
     if str(max(s1,s2,s3)) == str(s1):  #대각선 방향
      direction_matrix2[0][i][j] = 1
     if str(max(s1,s2,s3)) == str(s2):
      direction_matrix2[1][i][j] = 1
     if str(max(s1,s2,s3)) == str(s3):
      direction_matrix2[2][i][j] = 1

  for i in range(2,len(seq2)+2,1):
   for j in range(2,len(seq1)+2,1):
     s1 = int(score_matrix3[i-1][j-1]) + int(matrix_score3(score_matrix3[i][0],score_matrix3[0][j]))
     s2 = int(score_matrix3[i-1][j]) + int(gap_opening)
     s3 = int(score_matrix3[i][j-1]) + int(gap_opening)
     
     score_matrix3[i][j] = str(max(s1,s2,s3))
     if str(max(s1,s2,s3)) == str(s1):  #대각선 방향
      direction_matrix3[0][i][j] = 1
     if str(max(s1,s2,s3)) == str(s2):
      direction_matrix3[1][i][j] = 1
     if str(max(s1,s2,s3)) == str(s3):
      direction_matrix3[2][i][j] = 1

  for i in range(2,len(seq2)+2,1):
   for j in range(2,len(seq1)+2,1):
     s1 = int(score_matrix4[i-1][j-1]) + int(matrix_score4(score_matrix4[i][0],score_matrix4[0][j]))
     s2 = int(score_matrix4[i-1][j]) + int(gap_opening)
     s3 = int(score_matrix4[i][j-1]) + int(gap_opening)
     
     score_matrix4[i][j] = str(max(s1,s2,s3))
     if str(max(s1,s2,s3)) == str(s1):  #대각선 방향
      direction_matrix4[0][i][j] = 1
     if str(max(s1,s2,s3)) == str(s2):
      direction_matrix4[1][i][j] = 1
     if str(max(s1,s2,s3)) == str(s3):
      direction_matrix4[2][i][j] = 1

  for i in range(2,len(seq2)+2,1):
   for j in range(2,len(seq1)+2,1):
     s1 = int(score_matrix5[i-1][j-1]) + int(matrix_score5(score_matrix5[i][0],score_matrix5[0][j]))
     s2 = int(score_matrix5[i-1][j]) + int(gap_opening)
     s3 = int(score_matrix5[i][j-1]) + int(gap_opening)
     
     score_matrix5[i][j] = str(max(s1,s2,s3))
     if str(max(s1,s2,s3)) == str(s1):  #대각선 방향
      direction_matrix5[0][i][j] = 1
     if str(max(s1,s2,s3)) == str(s2):
      direction_matrix5[1][i][j] = 1
     if str(max(s1,s2,s3)) == str(s3):
      direction_matrix5[2][i][j] = 1

  for i in range(2,len(seq2)+2,1):
   for j in range(2,len(seq1)+2,1):
     s1 = int(score_matrix6[i-1][j-1]) + int(matrix_score6(score_matrix6[i][0],score_matrix6[0][j]))
     s2 = int(score_matrix6[i-1][j]) + int(gap_opening)
     s3 = int(score_matrix6[i][j-1]) + int(gap_opening)
     
     score_matrix6[i][j] = str(max(s1,s2,s3))
     if str(max(s1,s2,s3)) == str(s1):  #대각선 방향
      direction_matrix6[0][i][j] = 1
     if str(max(s1,s2,s3)) == str(s2):
      direction_matrix6[1][i][j] = 1
     if str(max(s1,s2,s3)) == str(s3):
      direction_matrix6[2][i][j] = 1

  for i in range(2,len(seq2)+2,1):
   for j in range(2,len(seq1)+2,1):
     s1 = int(score_matrix7[i-1][j-1]) + int(matrix_score7(score_matrix7[i][0],score_matrix7[0][j]))
     s2 = int(score_matrix7[i-1][j]) + int(gap_opening)
     s3 = int(score_matrix7[i][j-1]) + int(gap_opening)
     
     score_matrix7[i][j] = str(max(s1,s2,s3))
     if str(max(s1,s2,s3)) == str(s1):  #대각선 방향
      direction_matrix7[0][i][j] = 1
     if str(max(s1,s2,s3)) == str(s2):
      direction_matrix7[1][i][j] = 1
     if str(max(s1,s2,s3)) == str(s3):
      direction_matrix7[2][i][j] = 1

  for i in range(2,len(seq2)+2,1):
   for j in range(2,len(seq1)+2,1):
     s1 = int(score_matrix8[i-1][j-1]) + int(matrix_score8(score_matrix8[i][0],score_matrix8[0][j]))
     s2 = int(score_matrix8[i-1][j]) + int(gap_opening)
     s3 = int(score_matrix8[i][j-1]) + int(gap_opening)
     
     score_matrix8[i][j] = str(max(s1,s2,s3))
     if str(max(s1,s2,s3)) == str(s1):  #대각선 방향
      direction_matrix8[0][i][j] = 1
     if str(max(s1,s2,s3)) == str(s2):
      direction_matrix8[1][i][j] = 1
     if str(max(s1,s2,s3)) == str(s3):
      direction_matrix8[2][i][j] = 1
  ### 
  seqstore1 = []
  seqstore2 = []

  start_seq1_BLOSUM62 = len(seq1)+1
  start_seq2_BLOSUM62 = len(seq2)+1
  rev_seq1_BLOSUM62 = []
  rev_seq2_BLOSUM62 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print("바깥 i 는 ",i)
      #print("바깥 j 는 ",j)

      if i == start_seq2_BLOSUM62 and j == start_seq1_BLOSUM62:

        #print("안쪽 i 는 ",i)
        #print("안쪽 j 는 ",j)
        #print("start_seq2 는 ",start_seq2)
        #print("start_seq1 은 ",start_seq1)
        
        if direction_matrix1[0][i][j] == 1:
          sc1 = int(score_matrix1[i-1][j-1])
        else:
          sc1 = -1000000
        
        if direction_matrix1[1][i][j] == 1:
          sc2 = int(score_matrix1[i-1][j])
        else:
          sc2 = -1000000
        
        if direction_matrix1[2][i][j] == 1:
          sc3 = int(score_matrix1[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1_BLOSUM62.append(score_matrix1[0][j])
          rev_seq2_BLOSUM62.append(score_matrix1[i][0])
          start_seq1_BLOSUM62 = start_seq1_BLOSUM62 - 1
          start_seq2_BLOSUM62 = start_seq2_BLOSUM62 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1_BLOSUM62.append('-')
          rev_seq2_BLOSUM62.append(score_matrix1[i][0])
          start_seq2_BLOSUM62 = start_seq2_BLOSUM62 - 1
      
        else:
          rev_seq1_BLOSUM62.append(score_matrix1[0][j])
          rev_seq2_BLOSUM62.append('-')
          start_seq1_BLOSUM62 = start_seq1_BLOSUM62 - 1

        if start_seq2_BLOSUM62==1:
          while start_seq1_BLOSUM62 != 1:
            rev_seq1_BLOSUM62.append(score_matrix1[0][start_seq1_BLOSUM62])
            rev_seq2_BLOSUM62.append('-')
            start_seq1_BLOSUM62 = start_seq1_BLOSUM62 - 1

        elif start_seq1_BLOSUM62==1:
          while start_seq2_BLOSUM62 != 1:
            rev_seq1_BLOSUM62.append('-')
            rev_seq2_BLOSUM62.append(score_matrix1[start_seq2_BLOSUM62][0])
            start_seq2_BLOSUM62 = start_seq2_BLOSUM62 - 1

  rev_seq1_BLOSUM62.reverse()
  rev_seq2_BLOSUM62.reverse()
  best_seq1_BLOSUM62 = "".join(rev_seq1_BLOSUM62)
  best_seq2_BLOSUM62 = "".join(rev_seq2_BLOSUM62)
  seqstore1.append(best_seq1_BLOSUM62)
  seqstore2.append(best_seq2_BLOSUM62)

  sum_score_BLOSUM62 = 0
  gap_open_count = 0

  gap_extension_penalty = '-2'

  for i in range(len(rev_seq1_BLOSUM62)):
    
    a = rev_seq1_BLOSUM62[i]
    b = rev_seq2_BLOSUM62[i]

    if a == '-' or b == '-':
  
      if gap_open_count != 0:
        sum_score_BLOSUM62 = sum_score_BLOSUM62 + int(gap_extension_penalty)
      else:
        sum_score_BLOSUM62 = sum_score_BLOSUM62 + int(gap_opening)
        gap_open_count = 1

    else:
      c = matrix_score1(a,b)
      sum_score_BLOSUM62 = int(c) + sum_score_BLOSUM62
      gap_open_count = 0

  #print(sum_score_BLOSUM62)
  start_seq1_PAM250 = len(seq1)+1
  start_seq2_PAM250 = len(seq2)+1
  rev_seq1_PAM250 = []
  rev_seq2_PAM250 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print("바깥 i 는 ",i)
      #print("바깥 j 는 ",j)

      if i == start_seq2_PAM250 and j == start_seq1_PAM250:

        #print("안쪽 i 는 ",i)
        #print("안쪽 j 는 ",j)
        #print("start_seq2 는 ",start_seq2)
        #print("start_seq1 은 ",start_seq1)
        
        if direction_matrix2[0][i][j] == 1:
          sc1 = int(score_matrix2[i-1][j-1])
        else:
          sc1 = -1000000
        
        if direction_matrix2[1][i][j] == 1:
          sc2 = int(score_matrix2[i-1][j])
        else:
          sc2 = -1000000
        
        if direction_matrix2[2][i][j] == 1:
          sc3 = int(score_matrix2[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1_PAM250.append(score_matrix2[0][j])
          rev_seq2_PAM250.append(score_matrix2[i][0])
          start_seq1_PAM250 = start_seq1_PAM250 - 1
          start_seq2_PAM250 = start_seq2_PAM250 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1_PAM250.append('-')
          rev_seq2_PAM250.append(score_matrix2[i][0])
          start_seq2_PAM250 = start_seq2_PAM250 - 1
      
        else:
          rev_seq1_PAM250.append(score_matrix2[0][j])
          rev_seq2_PAM250.append('-')
          start_seq1_PAM250 = start_seq1_PAM250 - 1

        if start_seq2_PAM250==1:
          while start_seq1_PAM250 != 1:
            rev_seq1_PAM250.append(score_matrix2[0][start_seq1_PAM250])
            rev_seq2_PAM250.append('-')
            start_seq1_PAM250 = start_seq1_PAM250 - 1

        elif start_seq1_PAM250==1:
          while start_seq2_PAM250 != 1:
            rev_seq1_PAM250.append('-')
            rev_seq2_PAM250.append(score_matrix2[start_seq2_PAM250][0])
            start_seq2_PAM250 = start_seq2_PAM250 - 1
  rev_seq1_PAM250.reverse()
  rev_seq2_PAM250.reverse()
  best_seq1_PAM250 = "".join(rev_seq1_PAM250)
  best_seq2_PAM250 = "".join(rev_seq2_PAM250)
  seqstore1.append(best_seq1_PAM250)
  seqstore2.append(best_seq2_PAM250)

  sum_score_PAM250 = 0
  gap_open_count = 0

  gap_extension_penalty = '-2'

  for i in range(len(rev_seq1_PAM250)):
    
    a = rev_seq1_PAM250[i]
    b = rev_seq2_PAM250[i]

    if a == '-' or b == '-':
  
      if gap_open_count != 0:
        sum_score_PAM250 = sum_score_PAM250 + int(gap_extension_penalty)
      else:
        sum_score_PAM250 = sum_score_PAM250 + int(gap_opening)
        gap_open_count = 1

    else:
      c = matrix_score2(a,b)
      sum_score_PAM250 = int(c) + sum_score_PAM250
      gap_open_count = 0
    
  start_seq1_PAM30 = len(seq1)+1
  start_seq2_PAM30 = len(seq2)+1
  rev_seq1_PAM30 = []
  rev_seq2_PAM30 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print("바깥 i 는 ",i)
      #print("바깥 j 는 ",j)

      if i == start_seq2_PAM30 and j == start_seq1_PAM30:

        #print("안쪽 i 는 ",i)
        #print("안쪽 j 는 ",j)
        #print("start_seq2 는 ",start_seq2)
        #print("start_seq1 은 ",start_seq1)
        
        if direction_matrix3[0][i][j] == 1:
          sc1 = int(score_matrix3[i-1][j-1])
        else:
          sc1 = -1000000
        
        if direction_matrix3[1][i][j] == 1:
          sc2 = int(score_matrix3[i-1][j])
        else:
          sc2 = -1000000
        
        if direction_matrix3[2][i][j] == 1:
          sc3 = int(score_matrix3[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1_PAM30.append(score_matrix3[0][j])
          rev_seq2_PAM30.append(score_matrix3[i][0])
          start_seq1_PAM30 = start_seq1_PAM30 - 1
          start_seq2_PAM30 = start_seq2_PAM30 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1_PAM30.append('-')
          rev_seq2_PAM30.append(score_matrix3[i][0])
          start_seq2_PAM30 = start_seq2_PAM30 - 1
      
        else:
          rev_seq1_PAM30.append(score_matrix3[0][j])
          rev_seq2_PAM30.append('-')
          start_seq1_PAM30 = start_seq1_PAM30 - 1

        if start_seq2_PAM30==1:
          while start_seq1_PAM30 != 1:
            rev_seq1_PAM30.append(score_matrix3[0][start_seq1_PAM30])
            rev_seq2_PAM30.append('-')
            start_seq1_PAM30 = start_seq1_PAM30 - 1

        elif start_seq1_PAM30==1:
          while start_seq2_PAM30 != 1:
            rev_seq1_PAM30.append('-')
            rev_seq2_PAM30.append(score_matrix3[start_seq2_PAM30][0])
            start_seq2_PAM30 = start_seq2_PAM30 - 1

  rev_seq1_PAM30.reverse()
  rev_seq2_PAM30.reverse()
  best_seq1_PAM30 = "".join(rev_seq1_PAM30)
  best_seq2_PAM30 = "".join(rev_seq2_PAM30)
  seqstore1.append(best_seq1_PAM30)
  seqstore2.append(best_seq2_PAM30)

  sum_score_PAM30 = 0
  gap_open_count = 0

  gap_extension_penalty = '-2'

  for i in range(len(rev_seq1_PAM30)):
    
    a = rev_seq1_PAM30[i]
    b = rev_seq2_PAM30[i]

    if a == '-' or b == '-':
  
      if gap_open_count != 0:
        sum_score_PAM30 = sum_score_PAM30 + int(gap_extension_penalty)
      else:
        sum_score_PAM30 = sum_score_PAM30 + int(gap_opening)
        gap_open_count = 1

    else:
      c = matrix_score3(a,b)
      sum_score_PAM30 = int(c) + sum_score_PAM30
      gap_open_count = 0

  start_seq1_PAM70 = len(seq1)+1
  start_seq2_PAM70 = len(seq2)+1
  rev_seq1_PAM70 = []
  rev_seq2_PAM70 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print("바깥 i 는 ",i)
      #print("바깥 j 는 ",j)

      if i == start_seq2_PAM70 and j == start_seq1_PAM70:

        #print("안쪽 i 는 ",i)
        #print("안쪽 j 는 ",j)
        #print("start_seq2 는 ",start_seq2)
        #print("start_seq1 은 ",start_seq1)
        
        if direction_matrix4[0][i][j] == 1:
          sc1 = int(score_matrix4[i-1][j-1])
        else:
          sc1 = -1000000
        
        if direction_matrix4[1][i][j] == 1:
          sc2 = int(score_matrix4[i-1][j])
        else:
          sc2 = -1000000
        
        if direction_matrix4[2][i][j] == 1:
          sc3 = int(score_matrix4[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1_PAM70.append(score_matrix4[0][j])
          rev_seq2_PAM70.append(score_matrix4[i][0])
          start_seq1_PAM70 = start_seq1_PAM70 - 1
          start_seq2_PAM70 = start_seq2_PAM70 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1_PAM70.append('-')
          rev_seq2_PAM70.append(score_matrix4[i][0])
          start_seq2_PAM70 = start_seq2_PAM70 - 1
      
        else:
          rev_seq1_PAM70.append(score_matrix4[0][j])
          rev_seq2_PAM70.append('-')
          start_seq1_PAM70 = start_seq1_PAM70 - 1

        if start_seq2_PAM70==1:
          while start_seq1_PAM70 != 1:
            rev_seq1_PAM70.append(score_matrix4[0][start_seq1_PAM70])
            rev_seq2_PAM70.append('-')
            start_seq1_PAM70 = start_seq1_PAM70 - 1

        elif start_seq1_PAM70==1:
          while start_seq2_PAM70 != 1:
            rev_seq1_PAM70.append('-')
            rev_seq2_PAM70.append(score_matrix4[start_seq2_PAM70][0])
            start_seq2_PAM70 = start_seq2_PAM70 - 1
  rev_seq1_PAM70.reverse()
  rev_seq2_PAM70.reverse()
  best_seq1_PAM70 = "".join(rev_seq1_PAM70)
  best_seq2_PAM70 = "".join(rev_seq2_PAM70)
  seqstore1.append(best_seq1_PAM70)
  seqstore2.append(best_seq2_PAM70)

  sum_score_PAM70 = 0
  gap_open_count = 0

  gap_extension_penalty = '-2'

  for i in range(len(rev_seq1_PAM70)):
    
    a = rev_seq1_PAM70[i]
    b = rev_seq2_PAM70[i]

    if a == '-' or b == '-':
  
      if gap_open_count != 0:
        sum_score_PAM70 = sum_score_PAM70 + int(gap_extension_penalty)
      else:
        sum_score_PAM70 = sum_score_PAM70 + int(gap_opening)
        gap_open_count = 1

    else:
      c = matrix_score4(a,b)
      sum_score_PAM70 = int(c) + sum_score_PAM70
      gap_open_count = 0

  start_seq1_BLOSUM45 = len(seq1)+1
  start_seq2_BLOSUM45 = len(seq2)+1
  rev_seq1_BLOSUM45 = []
  rev_seq2_BLOSUM45 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print("바깥 i 는 ",i)
      #print("바깥 j 는 ",j)

      if i == start_seq2_BLOSUM45 and j == start_seq1_BLOSUM45:

        #print("안쪽 i 는 ",i)
        #print("안쪽 j 는 ",j)
        #print("start_seq2 는 ",start_seq2)
        #print("start_seq1 은 ",start_seq1)
        
        if direction_matrix5[0][i][j] == 1:
          sc1 = int(score_matrix5[i-1][j-1])
        else:
          sc1 = -1000000
        
        if direction_matrix5[1][i][j] == 1:
          sc2 = int(score_matrix5[i-1][j])
        else:
          sc2 = -1000000
        
        if direction_matrix5[2][i][j] == 1:
          sc3 = int(score_matrix5[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1_BLOSUM45.append(score_matrix5[0][j])
          rev_seq2_BLOSUM45.append(score_matrix5[i][0])
          start_seq1_BLOSUM45 = start_seq1_BLOSUM45 - 1
          start_seq2_BLOSUM45 = start_seq2_BLOSUM45 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1_BLOSUM45.append('-')
          rev_seq2_BLOSUM45.append(score_matrix5[i][0])
          start_seq2_BLOSUM45 = start_seq2_BLOSUM45 - 1
      
        else:
          rev_seq1_BLOSUM45.append(score_matrix5[0][j])
          rev_seq2_BLOSUM45.append('-')
          start_seq1_BLOSUM45 = start_seq1_BLOSUM45 - 1

        if start_seq2_BLOSUM45==1:
          while start_seq1_BLOSUM45 != 1:
            rev_seq1_BLOSUM45.append(score_matrix5[0][start_seq1_BLOSUM45])
            rev_seq2_BLOSUM45.append('-')
            start_seq1_BLOSUM45 = start_seq1_BLOSUM45 - 1

        elif start_seq1_BLOSUM45==1:
          while start_seq2_BLOSUM45 != 1:
            rev_seq1_BLOSUM45.append('-')
            rev_seq2_BLOSUM45.append(score_matrix5[start_seq2_BLOSUM45][0])
            start_seq2_BLOSUM45 = start_seq2_BLOSUM45 - 1

  rev_seq1_BLOSUM45.reverse()
  rev_seq2_BLOSUM45.reverse()
  best_seq1_BLOSUM45 = "".join(rev_seq1_BLOSUM45)
  best_seq2_BLOSUM45 = "".join(rev_seq2_BLOSUM45)
  seqstore1.append(best_seq1_BLOSUM45)
  seqstore2.append(best_seq2_BLOSUM45)

  sum_score_BLOSUM45 = 0
  gap_open_count = 0

  gap_extension_penalty = '-2'

  for i in range(len(rev_seq1_BLOSUM45)):
    
    a = rev_seq1_BLOSUM45[i]
    b = rev_seq2_BLOSUM45[i]

    if a == '-' or b == '-':
  
      if gap_open_count != 0:
        sum_score_BLOSUM45 = sum_score_BLOSUM45 + int(gap_extension_penalty)
      else:
        sum_score_BLOSUM45 = sum_score_BLOSUM45 + int(gap_opening)
        gap_open_count = 1

    else:
      c = matrix_score5(a,b)
      sum_score_BLOSUM45 = int(c) + sum_score_BLOSUM45
      gap_open_count = 0

  start_seq1_BLOSUM50 = len(seq1)+1
  start_seq2_BLOSUM50 = len(seq2)+1
  rev_seq1_BLOSUM50 = []
  rev_seq2_BLOSUM50 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print("바깥 i 는 ",i)
      #print("바깥 j 는 ",j)

      if i == start_seq2_BLOSUM50 and j == start_seq1_BLOSUM50:

        #print("안쪽 i 는 ",i)
        #print("안쪽 j 는 ",j)
        #print("start_seq2 는 ",start_seq2)
        #print("start_seq1 은 ",start_seq1)
        
        if direction_matrix6[0][i][j] == 1:
          sc1 = int(score_matrix6[i-1][j-1])
        else:
          sc1 = -1000000
        
        if direction_matrix6[1][i][j] == 1:
          sc2 = int(score_matrix6[i-1][j])
        else:
          sc2 = -1000000
        
        if direction_matrix6[2][i][j] == 1:
          sc3 = int(score_matrix6[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1_BLOSUM50.append(score_matrix6[0][j])
          rev_seq2_BLOSUM50.append(score_matrix6[i][0])
          start_seq1_BLOSUM50 = start_seq1_BLOSUM50 - 1
          start_seq2_BLOSUM50 = start_seq2_BLOSUM50 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1_BLOSUM50.append('-')
          rev_seq2_BLOSUM50.append(score_matrix6[i][0])
          start_seq2_BLOSUM50 = start_seq2_BLOSUM50 - 1
      
        else:
          rev_seq1_BLOSUM50.append(score_matrix6[0][j])
          rev_seq2_BLOSUM50.append('-')
          start_seq1_BLOSUM50 = start_seq1_BLOSUM50 - 1

        if start_seq2_BLOSUM50==1:
          while start_seq1_BLOSUM50 != 1:
            rev_seq1_BLOSUM50.append(score_matrix6[0][start_seq1_BLOSUM50])
            rev_seq2_BLOSUM50.append('-')
            start_seq1_BLOSUM50 = start_seq1_BLOSUM50 - 1

        elif start_seq1_BLOSUM50==1:
          while start_seq2_BLOSUM50 != 1:
            rev_seq1_BLOSUM50.append('-')
            rev_seq2_BLOSUM50.append(score_matrix6[start_seq2_BLOSUM50][0])
            start_seq2_BLOSUM50 = start_seq2_BLOSUM50 - 1

  rev_seq1_BLOSUM50.reverse()
  rev_seq2_BLOSUM50.reverse()
  best_seq1_BLOSUM50 = "".join(rev_seq1_BLOSUM50)
  best_seq2_BLOSUM50 = "".join(rev_seq2_BLOSUM50)
  seqstore1.append(best_seq1_BLOSUM50)
  seqstore2.append(best_seq2_BLOSUM50)

  sum_score_BLOSUM50 = 0
  gap_open_count = 0

  gap_extension_penalty = '-2'

  for i in range(len(rev_seq1_BLOSUM50)):
    
    a = rev_seq1_BLOSUM50[i]
    b = rev_seq2_BLOSUM50[i]

    if a == '-' or b == '-':
  
      if gap_open_count != 0:
        sum_score_BLOSUM50 = sum_score_BLOSUM50 + int(gap_extension_penalty)
      else:
        sum_score_BLOSUM50 = sum_score_BLOSUM50 + int(gap_opening)
        gap_open_count = 1

    else:
      c = matrix_score6(a,b)
      sum_score_BLOSUM50 = int(c) + sum_score_BLOSUM50
      gap_open_count = 0
      
  start_seq1_BLOSUM80 = len(seq1)+1
  start_seq2_BLOSUM80 = len(seq2)+1
  rev_seq1_BLOSUM80 = []
  rev_seq2_BLOSUM80 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print("바깥 i 는 ",i)
      #print("바깥 j 는 ",j)

      if i == start_seq2_BLOSUM80 and j == start_seq1_BLOSUM80:

        #print("안쪽 i 는 ",i)
        #print("안쪽 j 는 ",j)
        #print("start_seq2 는 ",start_seq2)
        #print("start_seq1 은 ",start_seq1)
        
        if direction_matrix7[0][i][j] == 1:
          sc1 = int(score_matrix7[i-1][j-1])
        else:
          sc1 = -1000000
        
        if direction_matrix7[1][i][j] == 1:
          sc2 = int(score_matrix7[i-1][j])
        else:
          sc2 = -1000000
        
        if direction_matrix7[2][i][j] == 1:
          sc3 = int(score_matrix7[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1_BLOSUM80.append(score_matrix7[0][j])
          rev_seq2_BLOSUM80.append(score_matrix7[i][0])
          start_seq1_BLOSUM80 = start_seq1_BLOSUM80 - 1
          start_seq2_BLOSUM80 = start_seq2_BLOSUM80 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1_BLOSUM80.append('-')
          rev_seq2_BLOSUM80.append(score_matrix7[i][0])
          start_seq2_BLOSUM80 = start_seq2_BLOSUM80 - 1
      
        else:
          rev_seq1_BLOSUM80.append(score_matrix7[0][j])
          rev_seq2_BLOSUM80.append('-')
          start_seq1_BLOSUM80 = start_seq1_BLOSUM80 - 1

        if start_seq2_BLOSUM80==1:
          while start_seq1_BLOSUM80 != 1:
            rev_seq1_BLOSUM80.append(score_matrix7[0][start_seq1_BLOSUM80])
            rev_seq2_BLOSUM80.append('-')
            start_seq1_BLOSUM80 = start_seq1_BLOSUM80 - 1

        elif start_seq1_BLOSUM80==1:
          while start_seq2_BLOSUM80 != 1:
            rev_seq1_BLOSUM80.append('-')
            rev_seq2_BLOSUM80.append(score_matrix7[start_seq2_BLOSUM80][0])
            start_seq2_BLOSUM80 = start_seq2_BLOSUM80 - 1
  rev_seq1_BLOSUM80.reverse()
  rev_seq2_BLOSUM80.reverse()
  best_seq1_BLOSUM80 = "".join(rev_seq1_BLOSUM80)
  best_seq2_BLOSUM80 = "".join(rev_seq2_BLOSUM80)
  seqstore1.append(best_seq1_BLOSUM80)
  seqstore2.append(best_seq2_BLOSUM80)
      
  sum_score_BLOSUM80 = 0
  gap_open_count = 0

  gap_extension_penalty = '-2'

  for i in range(len(rev_seq1_BLOSUM80)):
    
    a = rev_seq1_BLOSUM80[i]
    b = rev_seq2_BLOSUM80[i]

    if a == '-' or b == '-':
  
      if gap_open_count != 0:
        sum_score_BLOSUM80 = sum_score_BLOSUM80 + int(gap_extension_penalty)
      else:
        sum_score_BLOSUM80 = sum_score_BLOSUM80 + int(gap_opening)
        gap_open_count = 1

    else:
      c = matrix_score7(a,b)
      sum_score_BLOSUM80 = int(c) + sum_score_BLOSUM80
      gap_open_count = 0
      
  start_seq1_BLOSUM90 = len(seq1)+1
  start_seq2_BLOSUM90 = len(seq2)+1
  rev_seq1_BLOSUM90 = []
  rev_seq2_BLOSUM90 = []

  for i in range(len(seq2)+1,1,-1):
    for j in range(len(seq1)+1,1,-1):
      #print("바깥 i 는 ",i)
      #print("바깥 j 는 ",j)

      if i == start_seq2_BLOSUM90 and j == start_seq1_BLOSUM90:

        #print("안쪽 i 는 ",i)
        #print("안쪽 j 는 ",j)
        #print("start_seq2 는 ",start_seq2)
        #print("start_seq1 은 ",start_seq1)
        
        if direction_matrix8[0][i][j] == 1:
          sc1 = int(score_matrix8[i-1][j-1])
        else:
          sc1 = -1000000
        
        if direction_matrix8[1][i][j] == 1:
          sc2 = int(score_matrix8[i-1][j])
        else:
          sc2 = -1000000
        
        if direction_matrix8[2][i][j] == 1:
          sc3 = int(score_matrix8[i][j-1])
        else:
          sc3 = -1000000

        if str(max(sc1,sc2,sc3)) == str(sc1):
          rev_seq1_BLOSUM90.append(score_matrix8[0][j])
          rev_seq2_BLOSUM90.append(score_matrix8[i][0])
          start_seq1_BLOSUM90 = start_seq1_BLOSUM90 - 1
          start_seq2_BLOSUM90 = start_seq2_BLOSUM90 - 1

        elif str(max(sc1,sc2,sc3)) == str(sc2):
          rev_seq1_BLOSUM90.append('-')
          rev_seq2_BLOSUM90.append(score_matrix8[i][0])
          start_seq2_BLOSUM90 = start_seq2_BLOSUM90 - 1
      
        else:
          rev_seq1_BLOSUM90.append(score_matrix8[0][j])
          rev_seq2_BLOSUM90.append('-')
          start_seq1_BLOSUM90 = start_seq1_BLOSUM90 - 1

        if start_seq2_BLOSUM90==1:
          while start_seq1_BLOSUM90 != 1:
            rev_seq1_BLOSUM90.append(score_matrix8[0][start_seq1_BLOSUM90])
            rev_seq2_BLOSUM90.append('-')
            start_seq1_BLOSUM90 = start_seq1_BLOSUM90 - 1

        elif start_seq1_BLOSUM90==1:
          while start_seq2_BLOSUM90 != 1:
            rev_seq1_BLOSUM90.append('-')
            rev_seq2_BLOSUM90.append(score_matrix8[start_seq2_BLOSUM90][0])
            start_seq2_BLOSUM90 = start_seq2_BLOSUM90 - 1

  rev_seq1_BLOSUM90.reverse()
  rev_seq2_BLOSUM90.reverse()
  best_seq1_BLOSUM90 = "".join(rev_seq1_BLOSUM90)
  best_seq2_BLOSUM90 = "".join(rev_seq2_BLOSUM90)
  seqstore1.append(best_seq1_BLOSUM90)
  seqstore2.append(best_seq2_BLOSUM90)

  sum_score_BLOSUM90 = 0
  gap_open_count = 0

  gap_extension_penalty = '-2'

  for i in range(len(rev_seq1_BLOSUM90)):
    
    a = rev_seq1_BLOSUM90[i]
    b = rev_seq2_BLOSUM90[i]

    if a == '-' or b == '-':
  
      if gap_open_count != 0:
        sum_score_BLOSUM90 = sum_score_BLOSUM90 + int(gap_extension_penalty)
      else:
        sum_score_BLOSUM90 = sum_score_BLOSUM90 + int(gap_opening)
        gap_open_count = 1

    else:
      c = matrix_score8(a,b)
      sum_score_BLOSUM90 = int(c) + sum_score_BLOSUM90
      gap_open_count = 0

  score_arr = [sum_score_BLOSUM62,
  sum_score_PAM250,
  sum_score_PAM30,
  sum_score_PAM70,
  sum_score_BLOSUM45,
  sum_score_BLOSUM50,
  sum_score_BLOSUM80,
  sum_score_BLOSUM90]

  print("sum_score : BLOSUM62,PAM250,PAM30,PAM70,BLOSUM45,BLOSUM50,BLOSUM80,BLOSUM90 순으로")
  print(score_arr)

  matrix_lists = ['1.BLOSUM62','2.PAM250','3.PAM30','4.PAM70','5.BLOSUM45','6.BLOSUM50','7.BLOSUM80','8.BLOSUM90']
  max = score_arr[0]

  for d in range(len(score_arr)):
    if max < score_arr[d]:
      max = score_arr[d]
  
  print(max)
    
  for n in range(len(score_arr)):
    if score_arr[n] == max :
      print(f"[best seq1] {matrix_lists[n]} : {seqstore1[n]}, score = {max}")
      print(f"[best seq2] {matrix_lists[n]} : {seqstore2[n]}, score = {max}")
# Out:
# first seq : HEAGAWGHEE
# second seq : PAWHEAE
# gap opening penalty : -10
# gap extension penalty : -10
# sum_score : BLOSUM62,PAM250,PAM30,PAM70,BLOSUM45,BLOSUM50,BLOSUM80,BLOSUM90 순으로
# [-6, 1, 0, -4, 1, 0, -5, -6]
# 1
# [best seq1] 2.PAM250 : HEAGAWGHEE, score = 1
# [best seq2] 2.PAM250 : --P-AWHEAE, score = 1
# [best seq1] 5.BLOSUM45 : HEAGAWGHEE, score = 1
# [best seq2] 5.BLOSUM45 : -PA--WHEAE, score = 1
